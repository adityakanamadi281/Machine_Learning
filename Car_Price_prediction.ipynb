# %%
import pandas as pd
df=pd.read_csv("/content/ToyotaCorolla - MLR.csv")
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.shape
# Out:
# (1436, 11)

# %%
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Price        False
# Age_08_04    False
# KM           False
# Fuel_Type    False
# HP           False
# Automatic    False
# cc           False
# Doors        False
# Cylinders    False
# Gears        False
# Weight       False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histogram plot for numerical columns
df.hist(bins=30, figsize=(12,8))
plt.show()

# %%
df.plot(kind="box",figsize=(12,8))
plt.show()

# %%
# Converting categorical data to numerical data

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Fuel_Type']=le.fit_transform(df['Fuel_Type'])
df
# Out:
#       Price  Age_08_04     KM  Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986          1   90          0  2000      3
# 1     13750         23  72937          1   90          0  2000      3
# 2     13950         24  41711          1   90          0  2000      3
# 3     14950         26  48000          1   90          0  2000      3
# 4     13750         30  38500          1   90          0  2000      3
# ...     ...        ...    ...        ...  ...        ...   ...    ...
# 1431   7500         69  20544          2   86          0  1300      3
# 1432  10845         72  19000          2   86          0  1300      3
# 1433   8500         71  17016          2   86          0  1300      3
# 1434   7250         70  16916          2   86          0  1300      3
# 1435   6950         76      1          2  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# ...

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM    Fuel_Type           HP  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749     1.868384   101.502089
# std     3626.964585    18.599988   37506.448872     0.371572    14.981080
# min     4350.000000     1.000000       1.000000     0.000000    69.000000
# 25%     8450.000000    44.000000   43000.000000     2.000000    90.000000
# 50%     9900.000000    61.000000   63389.500000     2.000000   110.000000
# 75%    11950.000000    70.000000   87020.750000     2.000000   110.000000
# max    32500.000000    80.000000  243000.000000     2.000000   192.000000
#
#          Automatic           cc        Doors  Cylinders        Gears  \
# count  1436.000000   1436.00000  1436.000000     1436.0  1436.000000
# mean      0.055710   1576.85585     4.033426        4.0     5.026462
# std       0.229441    424.38677     0.952677        0.0     0.188510
# ...

# %%
z = df.drop("Cylinders",axis=1)
z
# Out:
#       Price  Age_08_04     KM  Fuel_Type   HP  Automatic    cc  Doors  Gears  \
# 0     13500         23  46986          1   90          0  2000      3      5
# 1     13750         23  72937          1   90          0  2000      3      5
# 2     13950         24  41711          1   90          0  2000      3      5
# 3     14950         26  48000          1   90          0  2000      3      5
# 4     13750         30  38500          1   90          0  2000      3      5
# ...     ...        ...    ...        ...  ...        ...   ...    ...    ...
# 1431   7500         69  20544          2   86          0  1300      3      5
# 1432  10845         72  19000          2   86          0  1300      3      5
# 1433   8500         71  17016          2   86          0  1300      3      5
# 1434   7250         70  16916          2   86          0  1300      3      5
# 1435   6950         76      1          2  110          0  1600      5      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
import seaborn as sns

# %%
correlation=z.corr(numeric_only=True)
correlation
# Out:
#               Price  Age_08_04        KM  Fuel_Type        HP  Automatic  \
# Price      1.000000  -0.876590 -0.569960  -0.022157  0.314990   0.033081
# Age_08_04 -0.876590   1.000000  0.505672   0.080261 -0.156622   0.031717
# KM        -0.569960   0.505672  1.000000  -0.420586 -0.333538  -0.081854
# Fuel_Type -0.022157   0.080261 -0.420586   1.000000  0.409476   0.069718
# HP         0.314990  -0.156622 -0.333538   0.409476  1.000000   0.013144
# Automatic  0.033081   0.031717 -0.081854   0.069718  0.013144   1.000000
# cc         0.126389  -0.098084  0.102683  -0.277239  0.035856   0.066740
# Doors      0.185326  -0.148359 -0.036197  -0.026935  0.092424  -0.027654
# Gears      0.063104  -0.005364  0.015023   0.069655  0.209477  -0.098555
# Weight     0.581198  -0.470253 -0.028598  -0.505303  0.089614   0.057249
#
#                  cc     Doors     Gears    Weight
# Price      0.126389  0.185326  0.063104  0.581198
# Age_08_04 -0.098084 -0.148359 -0.005364 -0.470253
# ...

# %%
sns.heatmap(correlation, annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Feature Engineering
x=df.drop("Price",axis=1)
x
# Out:
#       Age_08_04     KM  Fuel_Type   HP  Automatic    cc  Doors  Cylinders  \
# 0            23  46986          1   90          0  2000      3          4
# 1            23  72937          1   90          0  2000      3          4
# 2            24  41711          1   90          0  2000      3          4
# 3            26  48000          1   90          0  2000      3          4
# 4            30  38500          1   90          0  2000      3          4
# ...         ...    ...        ...  ...        ...   ...    ...        ...
# 1431         69  20544          2   86          0  1300      3          4
# 1432         72  19000          2   86          0  1300      3          4
# 1433         71  17016          2   86          0  1300      3          4
# 1434         70  16916          2   86          0  1300      3          4
# 1435         76      1          2  110          0  1600      5          4
#
#       Gears  Weight
# 0         5    1165
# 1         5    1165
# ...

# %%
# converting Price , rupees to EUROs

conversion_rate = 0.011
rupees= df["Price"]
euros= rupees * conversion_rate
euros
# Out:
# 0       148.500
# 1       151.250
# 2       153.450
# 3       164.450
# 4       151.250
#          ...
# 1431     82.500
# 1432    119.295
# 1433     93.500
# 1434     79.750
# 1435     76.450
# Name: Price, Length: 1436, dtype: float64

# %%
y=euros
y
# Out:
# 0       148.500
# 1       151.250
# 2       153.450
# 3       164.450
# 4       151.250
#          ...
# 1431     82.500
# 1432    119.295
# 1433     93.500
# 1434     79.750
# 1435     76.450
# Name: Price, Length: 1436, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=scaler.fit_transform(x)
x
# Out:
# array([[-1.77196633, -0.57469494, -2.33786794, ...,  0.        ,
#         -0.14042519,  1.75856113],
#        [-1.77196633,  0.11745379, -2.33786794, ...,  0.        ,
#         -0.14042519,  1.75856113],
#        [-1.71818412, -0.71538641, -2.33786794, ...,  0.        ,
#         -0.14042519,  1.75856113],
#        ...,
#        [ 0.80957948, -1.37403589,  0.35433604, ...,  0.        ,
#         -0.14042519, -1.09191497],
#        [ 0.75579727, -1.37670303,  0.35433604, ...,  0.        ,
#         -0.14042519, -1.09191497],
#        [ 1.0784905 , -1.82784925,  0.35433604, ...,  0.        ,
#         -0.14042519,  0.78939926]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model1=LinearRegression()
model1.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_train)
y_pred
# Out:
# array([ 99.43077156,  96.60280108, 149.51272608, ...,  87.33078091,
#         94.00882616,  71.55074445])

# %%
y_pred1=model1.predict(x_test)
y_pred1
# Out:
# array([129.45173013,  95.89372678,  99.20962396,  95.30472154,
#        107.72459595,  81.08382254,  95.82402335,  89.37080817,
#        152.69410396, 141.50356448,  98.17405151, 100.51857441,
#        139.95993859, 149.49795598, 105.03764111,  94.99939797,
#        140.88838057, 191.23937804,  78.27396194,  97.87813208,
#        140.63177355, 191.04389387,  84.12051579, 120.48122101,
#         84.2855319 , 169.43343613, 111.51853597,  77.76281105,
#        169.19136336, 157.67579786,  87.45374622, 109.19327337,
#         90.41735714, 109.67889299, 111.62010233,  85.65332512,
#         97.78935718, 108.16303973, 177.08341346, 100.95879965,
#        107.08143506, 103.2448944 ,  83.15645042,  62.93420156,
#         78.41691159, 179.98689037, 102.18497816, 114.24384598,
#        100.37205026, 145.61427336, 142.09328168,  73.30640383,
#        160.49643807, 170.50691977,  69.25032327,  81.52909716,
#        115.10934012, 116.00393133, 168.01862909, 244.1384935 ,
# ...

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred1)
score
# Out:
# 0.8750007618807176

# %%
score1=r2_score(y_train, y_pred)
score1
# Out:
# 0.8695032279244472

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
lasso=Lasso(alpha=50)

# %%
lasso.fit(x_train, y_train)
# Out:
# Lasso(alpha=50)

# %%
lasso_pred=lasso.predict(x_test)
lasso_pred
# Out:
# array([118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
#        118.29835017, 118.29835017, 118.29835017, 118.29835017,
# ...

# %%
lasso_score=r2_score(y_test, lasso_pred)
lasso_score
# Out:
# -0.0010352178542198942

# %%
lasso_pred1=lasso.predict(x_train)
lasso_pred1
# Out:
# array([118.29835017, 118.29835017, 118.29835017, ..., 118.29835017,
#        118.29835017, 118.29835017])

# %%
lasso_score1=r2_score(y_train, lasso_pred1)
lasso_score1
# Out:
# 0.0

# %%
#Ridge technique
ridge=Ridge(alpha=10)

# %%
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=10)

# %%
ridge_pred=ridge.predict(x_test)
ridge_pred
# Out:
# array([122.99668365,  98.71646133, 103.31555113,  98.76108398,
#        111.20309859,  87.26871098,  95.97067175,  91.24956554,
#        154.86649996, 144.3597441 , 104.56965671, 102.80833591,
#        142.38851213, 142.54974281, 107.65454607,  91.03083193,
#        134.31722599, 192.42744694,  81.79493029, 101.03793156,
#        139.63179522, 195.35683411,  87.08868633, 114.57541764,
#         82.72289042, 175.9743222 , 110.05029513,  81.22155274,
#        171.92351949, 159.2740974 ,  89.91682508, 107.17403131,
#         93.95241613, 111.27657136, 112.99407338,  88.80824979,
#         97.22515503, 109.81427456, 179.63287404, 105.58039782,
#        108.49391837, 104.85724069,  87.04373586,  61.44954456,
#         75.14800828, 188.58165757, 104.0406028 , 117.81898854,
#         96.02659788, 148.11786221, 142.74136361,  70.02078006,
#        163.98834332, 178.78032771,  67.15892104,  85.72505307,
#        113.76048525, 118.79903852, 176.66017778, 210.3147262 ,
# ...

# %%
ridge_score=r2_score(y_test, ridge_pred)
ridge_score
# Out:
# 0.8433805579482462

# %% [markdown]
# Conclusion:
# 1. Performed EDA
# 2. Build a Multiple Linear Regression model with 87% accuracy
# 3. Applied Lasso and Ridge techniques
